# %%
# https://www.interviewbit.com/problems/tiling-with-dominoes/

# %% [markdown]
# | Image 1                              | Image 2                              | Image 3
# | ------------------------------------ | ------------------------------------ | ---------------------------------- |
# | ![t1.jpeg](attachment:t1.jpeg) | ![t2.jpeg](attachment:t2.jpeg) | ![t3.jpeg](attachment:t3.jpeg)

# %%
mod = 10**9 + 7
class Solution:
    # @param A : integer
    # @return an integer
    def solve(self, A):
        def helper(n):
            if n % 2:
                return 0
            if n == 2:
                return 3
            if n == 4:
                return 11
            return 4 * helper(n - 2) - helper(n - 4)
        return helper(A) % mod

# %%
mod = 10**9 + 7
class Solution:
    # @param A : integer
    # @return an integer
    def solve(self, A):
        if A % 2:
            return 0
        dp = [-1] * max(A + 1, 5)
        dp[2] = 3
        dp[4] = 11
        for i in range(6, A + 1, 2):
            dp[i] = 4 * dp[i-2] - dp[i-4]
        return dp[A] % mod

# %%
mod = 10**9 + 7
class Solution:
    # @param A : integer
    # @return an integer
    def solve(self, A):
        if A % 2:
            return 0
        if A == 2:
            return 3
        if A == 5:
            return 11
        a = 3
        b = 11
        for i in range(6, A + 1, 2):
            c = 4 * b - a
            a = b
            b = c
        return b % mod

# %%
A = 4
sol = Solution()
sol.solve(A)
# Out:
# 11

# %%
A = 40
sol = Solution()
sol.solve(A)
# Out:
# 695102609

# %%
A = 100
sol = Solution()
sol.solve(A)
# Out:
# 436252889
