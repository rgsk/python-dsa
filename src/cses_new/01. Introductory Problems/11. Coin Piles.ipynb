# %%
import sys
sys.path.append('../..')
from lib.setup import setup, ii, li

# %%
@setup
def main():
    t = ii()
    for _ in range(t):
        a, b = li()
        if (a + b) % 3 == 0 and max(a, b) <= 2 * min(a, b):
            print("YES")
        else:
            print("NO")

# %%
input_txt = '''
3
2 1
2 2
3 3
'''

# %%
main()
# Out:
# YES
# NO
# YES
