# %%
import sys
sys.path.append('../..')
from lib.setup import setup, ii, li

# %%
@setup
def main():
    n = ii()
    count = 0
    i = 5
    while n // i > 0:
        count += n // i
        i *= 5
    print(count)

# %%
input_txt = '''
20
'''

# %%
main()
# Out:
# 4
