# %%
import sys
sys.path.append('..')
from lib.setup import setup, ii, li

# %%
@setup
def main():
    s = input()
    cur = s[0]
    count = 1
    max_count = 1
    for i in range(1, len(s)):
        if cur == s[i]:
            count += 1
        else:
            max_count = max(max_count, count)
            cur = s[i]
            count = 1
    max_count = max(max_count, count)
    print(max_count)

# %%
input_txt = '''
ATTCGGGA
'''

# %%
main()
# Out:
# 3
