# %%
import sys
sys.path.append('../..')
from lib.setup import setup, ii, li

# %%
mod = 1000000007

@setup
def main():
    n = ii()
    ans = 1
    for _ in range(n):
        ans *= 2
        ans %= mod
    print(ans)

# %%
input_txt = """
3
"""

# %%
main()
# Out:
# 8
