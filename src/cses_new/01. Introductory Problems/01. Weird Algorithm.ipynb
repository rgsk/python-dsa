# %%
import sys
sys.path.append('../..')
from lib.setup import setup, ii, li

# %%
@setup
def main():
    n = ii()
    while n != 1:
        print(n, end=" ")
        if n % 2:
            n = n * 3 + 1
        else:
            n //= 2
    print(1)

# %%
input_txt = """
3
"""

# %%
main()
# Out:
# 3 10 5 16 8 4 2 1

# %%
input_txt = """
4
"""

# %%
main()
# Out:
# 4 2 1
