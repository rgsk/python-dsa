# %%
import sys
sys.path.append('../..')
from lib.setup import setup, ii, li

# %%
@setup
def main():
    n = int(input())
    if n == 1:
        print(1)
    elif n <= 3:
        print('NO SOLUTION')
    else:
        for v in range(2, n + 1, 2):
            print(v, end=' ')
        for v in range(1, n + 1, 2):
            print(v, end=' ')
        print()

# %%
input_txt = '''
5
'''

# %%
main()
# Out:
# 2 4 1 3 5

# %%
input_txt = '''
3
'''

# %%
main()
# Out:
# NO SOLUTION
