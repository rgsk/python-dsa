# %%
import sys
sys.path.append('../..')
from lib.setup import setup
from main import ii, li, Counter, List, Any

# %%
@setup
def main():
    n = ii()
    arr = li()
    arr.sort()
    distinct = 1
    for i in range(1, n):
        if arr[i] != arr[i-1]:
            distinct += 1
    print(distinct)

# %%
input_txt = """
5
2 3 2 2 3
"""

# %%
main()
# Out:
# 2
