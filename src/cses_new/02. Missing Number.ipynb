# %%
import sys
sys.path.append('..')
from lib.setup import setup, ii, li

# %%
@setup
def main():
    n = ii()
    arr = li()
    xor = 0
    for i in range(1, n + 1):
        xor ^= i
    for v in arr:
        xor ^= v
    print(xor)

# %%
input_txt = """
5
2 3 1 5
"""

# %%
main()
# Out:
# 3
