# %%
import sys
sys.path.append('..')
from lib.setup import setup, ii, li

# %%
@setup
def main():
    n = ii()
    arr = li()
    m = 0
    for i in range(1, n + 1):
        m ^= i
    for v in arr:
        m ^= v
    print(m)

# %%
input_txt = """
5
2 3 1 5
"""

# %%
main()
# Out:
# 4
