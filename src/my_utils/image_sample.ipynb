# %%
import sys
sys.path.append('..')

# %%
from my_utils import image_utils

# %%
image_path = 'pexels-photo-1108099.jpeg'

# %%
image_utils.preview_image(image_path)

# %%
print(image_utils.describe_image(image_path))
# Out:
# The image features two puppies sitting together on a grassy area scattered with orange flower petals. They appear to be playful and happy, with their tongues out, enjoying the outdoors.
